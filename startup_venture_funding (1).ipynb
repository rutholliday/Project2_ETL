# %%
import pandas as pd
import matplotlib
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
funding_csv = "funding_08_14.csv"
funding_df = pd.read_csv(funding_csv)
funding_df = funding_df.set_index("Labels")
funding_df
# Out:
#                               2008  2009  2010  2011    2012  2013_2014
# Labels
# Rounds: angel                  401   290   366   522   573.0       1522
# Rounds: seed                   563   715   914  1379  1923.0      10810
# Rounds: venture               1704  4230  7014  3079  2971.0      15289
# Rounds: convertible_note         1     3     3     4    10.0        605
# Rounds: debt_financing          46   170   276   157   177.0       2930
# Rounds: grant                    5    69   121   117   114.0        794
# Rounds: post_ipo_debt            0     3     2     0     0.0         74
# Rounds: post_ipo_equity          4     7     5     1    14.0        314
# Rounds: private_equity          17    58    96    83    92.0        630
# Rounds: secondary_market         0     1     1     1     NaN         52
# Rounds: equity_crowdfunding      0     0     0     0     2.0       2258
# Rounds: product_crowdfunding     0     0     0     2     5.0        156
# ...

# %%
#connecting to my sql database
rds_connection_string = "root:Lucky0510!@127.0.0.1/funding_types"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# C:\Users\Seanj922\Anaconda4\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
# ['funding_types', 'funding_types1', 'funding_types2']

# %%
#Loading data to kickstarter mysql table
funding_df.to_sql(name='funding_types2', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda4\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda4\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# ~\Anaconda4\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\Anaconda4\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# ...
