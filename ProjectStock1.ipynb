# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
file = 'categories_amounts1.csv'

# %%
categories_df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
categories_df
# Out:
#              Categories   Amount(USD)2008   Amount(USD)2009   Amount(USD)2010  \
# 0         Biotechnology   $2,107,706,306    $6,086,891,457    $7,967,040,151
# 1              Software   $2,298,095,000    $2,386,021,661    $3,085,392,930
# 2            E-Commerce     $660,430,304      $549,543,693    $1,941,412,164
# 3           Health Care   $1,352,517,143    $2,345,619,383    $2,651,334,516
# 4   Enterprise Software     $917,707,308    $1,028,993,578    $1,450,213,882
# 5        Transportation   $1,352,137,318    $1,042,241,419    $1,353,896,474
# 6                Mobile     $442,362,477      $379,616,508      $527,293,702
# 7             Analytics     $225,523,777      $493,082,575      $525,131,995
# 8       Online Shopping     $661,593,857      $396,798,027      $592,538,338
# 9   Health and Wellness     $435,995,243      $433,085,252      $740,212,022
# 10          Curated Web   $4,550,421,149    $2,063,962,407    $2,877,812,656
# ...

# %%
#connecting to my sql database
rds_connection_string = "root:Lucky0510!@127.0.0.1/InvestmentCategories"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# C:\Users\Seanj922\Anaconda4\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
# ['investmentcategories', 'investmentcategory1']

# %%
#Loading data to kickstarter mysql table
categories_df.to_sql(name='investmentcategories', con=engine, if_exists='append', index=False)
